# %%
# Bootstrap: agrega la raíz del repo al path e importa init_agents
# (carga .env y configura la key de tracing de OpenAI)
import sys, pathlib
_root = pathlib.Path.cwd()
while not (_root / "init_agents.py").exists() and _root != _root.parent:
    _root = _root.parent
sys.path.append(str(_root))
import init_agents

# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por sk-proj-

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI()

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2+2 es 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Si cinco máquinas pueden fabricar cinco piezas en cinco minutos, ¿cuánto tiempo tardarán cien máquinas en fabricar cien piezas?

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Vamos a analizar el problema paso a paso:
#
# - **Datos del problema:**
#   - 5 máquinas fabrican 5 piezas en 5 minutos.
#
# - **Primero, encontremos la tasa de fabricación por máquina:**
#
#   5 máquinas → 5 piezas en 5 minutos
#   Entonces, 1 máquina → ¿cuántas piezas en 5 minutos?
#   Como las 5 máquinas juntas hacen 5 piezas, 1 máquina hace 1 pieza en 5 minutos.
#
# - **Ahora, con esa tasa:**
#
#   1 máquina fabrica 1 pieza en 5 minutos.
#
# - **Queremos calcular cuánto tiempo tardan 100 máquinas en fabricar 100 piezas.**
#
#   Cada máquina fabrica 1 pieza en 5 minutos, y 100 máquinas trabajando simultáneamente fabrican 100 piezas en el mismo tiempo.
#
# **Respuesta:**
#
# **5 minutos**
#
# Porque el número de máquinas y piezas aumentó proporcionalmente, el tiempo no cambia.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Vamos a analizar el problema paso a paso:
#
# - **Datos del problema:**
#   - 5 máquinas fabrican 5 piezas en 5 minutos.
#
# - **Primero, encontremos la tasa de fabricación por máquina:**
#
#   5 máquinas → 5 piezas en 5 minutos
#   Entonces, 1 máquina → ¿cuántas piezas en 5 minutos?
#   Como las 5 máquinas juntas hacen 5 piezas, 1 máquina hace 1 pieza en 5 minutos.
#
# - **Ahora, con esa tasa:**
#
#   1 máquina fabrica 1 pieza en 5 minutos.
#
# - **Queremos calcular cuánto tiempo tardan 100 máquinas en fabricar 100 piezas.**
#
#   Cada máquina fabrica 1 pieza en 5 minutos, y 100 máquinas trabajando simultáneamente fabrican 100 piezas en el mismo tiempo.
#
# **Respuesta:**
#
# **5 minutos**
#
# Porque el número de máquinas y piezas aumentó proporcionalmente, el tiempo no cambia.

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Priemro creamos el mensaje

messages = [{"role": "user", "content": "elije un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic"}]

# Hacemos la primera llamada:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Luego leemos la idea de negocio:

area_de_negocio = response.choices[0].message.content
print(area_de_negocio)

# Y repetimos!

messages = [{"role": "user", "content": f"presente un problema en la industria {area_de_negocio}, algo desafiante que pueda ser propicio para una solución con Agentic"}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)


business_idea = response.choices[0].message.content

messages = [{"role": "user", "content": f"propon la solución de IA con Agentic para el problema {business_idea}."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)


answer = response.choices[0].message.content
print(answer)
# Out:
# Una área de negocio que valdría mucho la pena explorar para una oportunidad de IA con Agentic es **la gestión de la cadena de suministro (Supply Chain Management)**.
#
# ### Por qué elegir la cadena de suministro para una solución Agentic:
#
# 1. **Complejidad y dinámica**: Las cadenas de suministro modernas son altamente complejas y están sujetas a cambios constantes por factores externos (demanda, oferta, clima, geopolítica). Una IA agentic puede actuar de manera autónoma para ajustar planes, negociar con proveedores o redirigir recursos en tiempo real.
#
# 2. **Necesidad de toma de decisiones en tiempo real**: En muchos casos, las decisiones deben tomarse en cuestión de minutos o segundos para evitar interrupciones o sobrecostos. Un agente autónomo puede monitorear todos los datos y actuar sin necesidad de intervención humana constante.
#
# 3. **Integración multiplataforma**: Los agentes pueden coordinar actividades entre diferentes sistemas, desde logística, inventario, hasta finanzas y compras, optimizando todo el proceso productivo y de entrega.
#
# 4. **Optimización de recursos**: Una IA agentic puede detectar oportunidades de ahorro en rutas de transporte, almacenamiento, o producción, y ejecutar cambios automáticamente, generando ahorros significativos.
#
# 5. **Mayor resiliencia**: Puede anticipar riesgos y generar planes de contingencia autónomos frente a interrupciones (p.ej., problemas con proveedores, desastres naturales).
#
# ### Ejemplo de caso de uso Agentic en la cadena de suministro:
# - Un agente que monitoree el inventario, análisis de demanda y estado de entregas.
# - Detecte una posible escasez inminente.
# - Negocie automáticamente con proveedores alternativos.
# - Reorganice y reasigne recursos logísticos en tiempo real para garantizar la continuidad del negocio.
#
# ---
#
# Si quieres, puedo ayudarte a profundizar en este caso o explorar otros sectores donde una IA agentic podría tener gran impacto. ¿Te interesa?
# ¡Claro! Me parece un problema sumamente bien planteado y un escenario ideal para una solución de IA agentic. Vamos a profundizar un poco más en cómo sería la propuesta de solución basada en agentes autónomos para esta gestión dinámica y simultánea de interrupciones en la cadena de suministro global.
#
# ---
#
# ## Propuesta de solución agentic para la gestión dinámica y autónoma de interrupciones en la cadena de suministro
#
# ---
#
# ### 1. Arquitectura general del sistema agentic
#
# #### a. **Agentes especializados y colaborativos**
#
# - **Agentes de monitoreo**
#   Capturan en tiempo real datos de múltiples fuentes: IoT (sensores, GPS), plataformas ERP, APIs logísticas, noticias y alertas geopolíticas, redes sociales, etc.
#
# - **Agentes diagnósticos**
#   Interpretan los datos recibidos, identifican interrupciones y estiman su impacto (ej. riesgos, demoras, costos).
#
# - **Agentes de planificación y optimización**
#   Recalculan instantáneamente los planes de producción, inventarios, rutas y entregas ajustando prioridades y recursos.
#
# - **Agentes de negociación**
#   Se comunican autónomamente con proveedores alternativos, transportistas y socios logísticos para renegociar plazos, condiciones o volumen.
#
# - **Agente de coordinación y orquestación**
#   Integra el trabajo de los distintos agentes, resuelve conflictos y garantiza coherencia y consistencia en las decisiones.
#
# - **Agente de aprendizaje**
#   Analiza resultados, mide desempeño y ajusta políticas y modelos predictivos para mejorar futuras respuestas.
#
# ---
#
# ### 2. Capacidades internas clave
#
# - **Multimodalidad y fusión de información**
#   El sistema combina datos estructurados, semi-estructurados y no estructurados para una visión holística.
#
# - **Toma de decisiones en entornos altamente dinámicos y multiagent**
#   Utilización de técnicas avanzadas como planificación de contingencias, algoritmos de optimización combinatoria, aprendizaje por refuerzo multiagente, y teoría de juegos para negociación.
#
# - **Comunicación natural y negociadora**
#   Los agentes de negociación utilizan procesamiento de lenguaje natural (PLN) para interactuar automática y eficazmente con humanos u otros sistemas.
#
# - **Automatización completa con supervisión humana opcional**
#   Las decisiones pueden ejecutarse automáticamente, pero también generar alertas y recomendaciones para el equipo humano.
#
# ---
#
# ### 3. Ejemplo de flujo en el caso de uso propuesto:
#
# | Paso                                            | Agente Responsable       | Acción                                                             |
# |-------------------------------------------------|--------------------------|--------------------------------------------------------------------|
# | Detección de interrupciones                      | Agentes de monitoreo     | Identifican cierre portuario, aumento demanda y retrasos regulatorios.  |
# | Análisis de impacto y prioridad                  | Agentes diagnósticos     | Prioriza urgencia y riesgos asociados a cada interrupción.         |
# | Replanificación y simulación de escenarios       | Agentes de planificación | Evalúan rutas alternativas, ajuste de producción e inventarios.   |
# | Negociación para abastecimiento alternativo       | Agentes de negociación   | Contactan y renegocian con proveedores/transportistas en otras regiones. |
# | Coordinación integrada y validación de plan       | Agente orquestador       | Fusiona propuestas y asegura la coherencia para la ejecución.      |
# | Ejecución automática o con supervisión humana     | Todos los agentes          | Implementan plan o presentan recomendaciones para validación.      |
# | Feedback y aprendizaje post-evento                | Agente de aprendizaje    | Actualiza modelos y estrategias basadas en resultados midiendo eficiencia y costos. |
#
# ---
#
# ### 4. Tecnologías y metodologías soportantes
#
# - **IA de agentes multiagente (MAS)** con frameworks como JADE, SPADE, o plataformas en cloud.
# - **Integración con sistemas ERP, TMS, WMS** vía APIs y middleware.
# - **Machine Learning**: modelos predictivos para demandas, riesgos y tiempos.
# - **Optimización combinatoria**: algoritmos heurísticos/metaheurísticos para rutas y inventarios.
# - **Procesamiento de lenguaje natural**: chatbots y agentes conversacionales.
# - **Sistemas de alerta en tiempo real** y paneles de control con visualizaciones avanzadas.
#
# ---
#
# ### 5. Beneficios esperados
#
# - Reducción drástica en tiempos de respuesta ante crisis.
# - Minimización de pérdidas económicas por interrupciones.
# - Incremento de la resiliencia y flexibilidad de la cadena de suministro.
# - Capacidad de aprendizaje continuo que mejora gestión de futuras crisis.
# - Mayor autonomía y reducción de carga para equipos humanos.
#
# ---
#
# Si deseas, podemos profundizar en:
#
# - Diseño detallado de cada tipo de agente.
# - Algoritmos de planificación y optimización específicos.
# - Integración con sistemas IT existentes.
# - Estrategias de entrenamiento y despliegue para modelos de ML.
# - Escenarios de simulación para benchmarking y validar la solución.
#
# ¿Quieres que avancemos en alguna de estas áreas o algún otro aspecto?

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# ¡Claro! Me parece un problema sumamente bien planteado y un escenario ideal para una solución de IA agentic. Vamos a profundizar un poco más en cómo sería la propuesta de solución basada en agentes autónomos para esta gestión dinámica y simultánea de interrupciones en la cadena de suministro global.
#
# ---
#
# ## Propuesta de solución agentic para la gestión dinámica y autónoma de interrupciones en la cadena de suministro
#
# ---
#
# ### 1. Arquitectura general del sistema agentic
#
# #### a. **Agentes especializados y colaborativos**
#
# - **Agentes de monitoreo**
#   Capturan en tiempo real datos de múltiples fuentes: IoT (sensores, GPS), plataformas ERP, APIs logísticas, noticias y alertas geopolíticas, redes sociales, etc.
#
# - **Agentes diagnósticos**
#   Interpretan los datos recibidos, identifican interrupciones y estiman su impacto (ej. riesgos, demoras, costos).
#
# - **Agentes de planificación y optimización**
#   Recalculan instantáneamente los planes de producción, inventarios, rutas y entregas ajustando prioridades y recursos.
#
# - **Agentes de negociación**
#   Se comunican autónomamente con proveedores alternativos, transportistas y socios logísticos para renegociar plazos, condiciones o volumen.
#
# - **Agente de coordinación y orquestación**
#   Integra el trabajo de los distintos agentes, resuelve conflictos y garantiza coherencia y consistencia en las decisiones.
#
# - **Agente de aprendizaje**
#   Analiza resultados, mide desempeño y ajusta políticas y modelos predictivos para mejorar futuras respuestas.
#
# ---
#
# ### 2. Capacidades internas clave
#
# - **Multimodalidad y fusión de información**
#   El sistema combina datos estructurados, semi-estructurados y no estructurados para una visión holística.
#
# - **Toma de decisiones en entornos altamente dinámicos y multiagent**
#   Utilización de técnicas avanzadas como planificación de contingencias, algoritmos de optimización combinatoria, aprendizaje por refuerzo multiagente, y teoría de juegos para negociación.
#
# - **Comunicación natural y negociadora**
#   Los agentes de negociación utilizan procesamiento de lenguaje natural (PLN) para interactuar automática y eficazmente con humanos u otros sistemas.
#
# - **Automatización completa con supervisión humana opcional**
#   Las decisiones pueden ejecutarse automáticamente, pero también generar alertas y recomendaciones para el equipo humano.
#
# ---
#
# ### 3. Ejemplo de flujo en el caso de uso propuesto:
#
# | Paso                                            | Agente Responsable       | Acción                                                             |
# |-------------------------------------------------|--------------------------|--------------------------------------------------------------------|
# | Detección de interrupciones                      | Agentes de monitoreo     | Identifican cierre portuario, aumento demanda y retrasos regulatorios.  |
# | Análisis de impacto y prioridad                  | Agentes diagnósticos     | Prioriza urgencia y riesgos asociados a cada interrupción.         |
# | Replanificación y simulación de escenarios       | Agentes de planificación | Evalúan rutas alternativas, ajuste de producción e inventarios.   |
# | Negociación para abastecimiento alternativo       | Agentes de negociación   | Contactan y renegocian con proveedores/transportistas en otras regiones. |
# | Coordinación integrada y validación de plan       | Agente orquestador       | Fusiona propuestas y asegura la coherencia para la ejecución.      |
# | Ejecución automática o con supervisión humana     | Todos los agentes          | Implementan plan o presentan recomendaciones para validación.      |
# | Feedback y aprendizaje post-evento                | Agente de aprendizaje    | Actualiza modelos y estrategias basadas en resultados midiendo eficiencia y costos. |
#
# ---
#
# ### 4. Tecnologías y metodologías soportantes
#
# - **IA de agentes multiagente (MAS)** con frameworks como JADE, SPADE, o plataformas en cloud.
# - **Integración con sistemas ERP, TMS, WMS** vía APIs y middleware.
# - **Machine Learning**: modelos predictivos para demandas, riesgos y tiempos.
# - **Optimización combinatoria**: algoritmos heurísticos/metaheurísticos para rutas y inventarios.
# - **Procesamiento de lenguaje natural**: chatbots y agentes conversacionales.
# - **Sistemas de alerta en tiempo real** y paneles de control con visualizaciones avanzadas.
#
# ---
#
# ### 5. Beneficios esperados
#
# - Reducción drástica en tiempos de respuesta ante crisis.
# - Minimización de pérdidas económicas por interrupciones.
# - Incremento de la resiliencia y flexibilidad de la cadena de suministro.
# - Capacidad de aprendizaje continuo que mejora gestión de futuras crisis.
# - Mayor autonomía y reducción de carga para equipos humanos.
#
# ---
#
# Si deseas, podemos profundizar en:
#
# - Diseño detallado de cada tipo de agente.
# - Algoritmos de planificación y optimización específicos.
# - Integración con sistemas IT existentes.
# - Estrategias de entrenamiento y despliegue para modelos de ML.
# - Escenarios de simulación para benchmarking y validar la solución.
#
# ¿Quieres que avancemos en alguna de estas áreas o algún otro aspecto?
